# %% [markdown]
# # 🔍 Understanding Data set before EDA

# %%
# Import all necessery libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec
from scipy import stats
import matplotlib.style as style
import missingno as msno

from scipy.stats import skew
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax, skew
style.use('fivethirtyeight')

# %% [markdown]
# # 📊 Importing the data set

# %%
dff=pd.read_csv("../Dataset/NigeriaInflationRates.csv")
dff
# Out:
#      Year  Month  Inflation_Rate  Crude Oil Price  Production  \
# 0    2008      1            8.60            94.26        2.17
# 1    2008      2            8.00            98.15        2.08
# 2    2008      3            7.80           103.73        2.06
# 3    2008      4            8.20           116.73        1.96
# 4    2008      5            9.70           126.57        2.05
# ..    ...    ...             ...              ...         ...
# 193  2024      2           31.70            86.08        1.32
# 194  2024      3           33.20            88.80        1.23
# 195  2024      4           33.69            93.12        1.28
# 196  2024      5           33.95            84.01        1.25
# 197  2024      6           34.19            83.64        1.28
#
#      Crude Oil Export    CPI_Food  CPI_Energy  CPI_Health  CPI_Transport  \
# 0                1.72   75.534431   84.612846   83.863139      86.530038
# ...

# %% [markdown]
# # 🧠 Understanding The Dataset
#
# This is done to better under the dataset itself just to get a scope of the data I'm working with.

# %%
dff.shape
# Out:
# (198, 12)

# %%
dff.head()
# Out:
#    Year  Month  Inflation_Rate  Crude Oil Price  Production  Crude Oil Export  \
# 0  2008      1             8.6            94.26        2.17              1.72
# 1  2008      2             8.0            98.15        2.08              1.63
# 2  2008      3             7.8           103.73        2.06              1.61
# 3  2008      4             8.2           116.73        1.96              1.51
# 4  2008      5             9.7           126.57        2.05              1.60
#
#     CPI_Food  CPI_Energy  CPI_Health  CPI_Transport  CPI_Communication  \
# 0  75.534431   84.612846   83.863139      86.530038          83.129440
# 1  75.154185   85.231632   83.365891      88.355236          82.889814
# 2  78.242523   83.251516   86.082993      84.376304          81.893471
# 3  79.434268   84.348830   89.445332      88.600334          93.937865
# 4  80.783677   85.574027   90.540461      87.932833          97.553285
#
#    CPI_Education
# 0      75.284466
# 1      75.457619
# ...

# %%
dff.tail()
# Out:
#      Year  Month  Inflation_Rate  Crude Oil Price  Production  \
# 193  2024      2           31.70            86.08        1.32
# 194  2024      3           33.20            88.80        1.23
# 195  2024      4           33.69            93.12        1.28
# 196  2024      5           33.95            84.01        1.25
# 197  2024      6           34.19            83.64        1.28
#
#      Crude Oil Export    CPI_Food  CPI_Energy  CPI_Health  CPI_Transport  \
# 193              0.87  846.846533  543.893969  494.844568     570.034088
# 194              0.78  877.472863  558.813016  502.912687     579.821453
# 195              0.83  899.453386  571.960431  510.095879     592.282753
# 196              0.80  920.005281  583.894158  517.391784     606.408076
# 197              0.83  943.458769  596.496022  524.747711     620.966251
#
#      CPI_Communication  CPI_Education
# 193         234.228948     469.899712
# 194         234.694654     476.890292
# ...

# %% [markdown]
# I can tell the data ranges from 2008-2024 which should me more than sufficient to help us achieve our objectives

# %%
dff.columns
# Out:
# Index(['Year', 'Month', 'Inflation_Rate', 'Crude Oil Price', 'Production',
#        'Crude Oil Export', 'CPI_Food', 'CPI_Energy', 'CPI_Health',
#        'CPI_Transport', 'CPI_Communication', 'CPI_Education'],
#       dtype='object')

# %%
dff.dtypes
# Out:
# Year                   int64
# Month                  int64
# Inflation_Rate       float64
# Crude Oil Price      float64
# Production           float64
# Crude Oil Export     float64
# CPI_Food             float64
# CPI_Energy           float64
# CPI_Health           float64
# CPI_Transport        float64
# CPI_Communication    float64
# CPI_Education        float64
# dtype: object

# %%
# Determining agregated values for numerical variables in the data set
dff.describe()
# Out:
#               Year       Month  Inflation_Rate  Crude Oil Price  Production  \
# count   198.000000  198.000000      198.000000       197.000000  197.000000
# mean   2015.757576    6.409091       14.068232        79.886599    1.921015
# std       4.779591    3.459603        5.456106        26.586380    0.412341
# min    2008.000000    1.000000        7.700000        14.280000    0.940000
# 25%    2012.000000    3.000000       10.625000        58.460000    1.650000
# 50%    2016.000000    6.000000       12.735000        77.540000    2.040000
# 75%    2020.000000    9.000000       16.040000       106.000000    2.210000
# max    2024.000000   12.000000       34.190000       138.740000    2.880000
#
#        Crude Oil Export    CPI_Food  CPI_Energy  CPI_Health  CPI_Transport  \
# count        197.000000  198.000000  198.000000  198.000000     198.000000
# mean           1.471015  276.715714  234.199688  208.020379     228.683823
# ...

# %% [markdown]
# # 💡 Data Preparation
#
# I need to modify the data a little bit so if won't affect my analysis later when need

# %% [markdown]
# ### Data Representation
#
#  *I need the work on the "Month" column and change the from being represented with number to actual months of the year, that way it will have better understanding when we are using the column for analysis"

# %%
month_mapping = {
    1: 'Jan',
    2: 'Feb',
    3: 'Mar',
    4: 'Apr',
    5: 'May',
    6: 'Jun',
    7: 'Jul',
    8: 'Aug',
    9: 'Sep',
    10: 'Oct',
    11: 'Nov',
    12: 'Dec'
}

# %%
dff['Month'] = pd.to_numeric(dff['Month'], errors='coerce')
dff=dff[dff['Month'].between(1, 12)]  # filter out invalid months
dff['Month'] = dff['Month'].astype(int).map(month_mapping)
dff
# Out:
#      Year Month  Inflation_Rate  Crude Oil Price  Production  \
# 0    2008   Jan            8.60            94.26        2.17
# 1    2008   Feb            8.00            98.15        2.08
# 2    2008   Mar            7.80           103.73        2.06
# 3    2008   Apr            8.20           116.73        1.96
# 4    2008   May            9.70           126.57        2.05
# ..    ...   ...             ...              ...         ...
# 193  2024   Feb           31.70            86.08        1.32
# 194  2024   Mar           33.20            88.80        1.23
# 195  2024   Apr           33.69            93.12        1.28
# 196  2024   May           33.95            84.01        1.25
# 197  2024   Jun           34.19            83.64        1.28
#
#      Crude Oil Export    CPI_Food  CPI_Energy  CPI_Health  CPI_Transport  \
# 0                1.72   75.534431   84.612846   83.863139      86.530038
# 1                1.63   75.154185   85.231632   83.365891      88.355236
# ...

# %% [markdown]
# ### 🔍 Checking for missing values
#
#  *Checking for null values I prefer to treat this before hand as missing value could create gap and bias during analysis

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               198 non-null    int64
#  1   Month              198 non-null    object
#  2   Inflation_Rate     198 non-null    float64
#  3   Crude Oil Price    197 non-null    float64
#  4   Production         197 non-null    float64
#  5   Crude Oil Export   197 non-null    float64
#  6   CPI_Food           198 non-null    float64
#  7   CPI_Energy         198 non-null    float64
#  8   CPI_Health         198 non-null    float64
#  9   CPI_Transport      198 non-null    float64
#  10  CPI_Communication  198 non-null    float64
#  11  CPI_Education      198 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 18.7+ KB

# %% [markdown]
# ### 🔍 Checking for Duplicates
#
# *Even when there are no nulls I still want to check for duplicates row which can also skew analysis

# %%
duplicate_rows = dff[dff.duplicated()]
print(f"Duplicate rows: {len(duplicate_rows)}")
# Out:
# Duplicate rows: 0

# %%
## exporting my clean dataframe so I can use it elsewhere
dff.to_csv("cleaned_dataset.csv", index=False)
